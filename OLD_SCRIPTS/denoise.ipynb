# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# Function to denoise an image
def denoise_image(input_path, output_path):
    # Load image
    img = cv2.imread(input_path)
    
    # Apply Gaussian blur for noise reduction
    denoised_img = cv2.GaussianBlur(img, (5, 5), 0)
    
    # Save denoised image
    cv2.imwrite(output_path, denoised_img)

# %%
input_img='20220727/pass_9/ffc/frame_c305_20220727_180022.png'
output_dir = "denoised_frames_test/"

# %%
# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
img_colour = cv2.imread(input_img)

# %%
plt.imshow(img_colour)

# %%
img = cv2.imread(input_img, cv2.IMREAD_GRAYSCALE)

# %%
denoised_img_grey = cv2.bilateralFilter(img, 9, 75, 75)

# %%
plt.imshow(denoised_img_grey)

# %%
denoised_color_img = cv2.cvtColor(denoised_img_grey, cv2.COLOR_GRAY2BGR)

# %%
cv2.imwrite(os.path.join(output_dir, 'denoised.png'), denoised_color_img)
# Out:
# True

# %%
img = cv2.imread(os.path.join(output_dir, 'denoised.png'))

# %%
plt.imshow(denoised_color_img)

# %%
plt.imshow(img)

# %%
input_img='20220727/pass_21/ffc/frame_c305_20220727_185205.png'
output_dir = "denoised_frames_test/"

# %%
img = cv2.imread(input_img)
plt.imshow(img)

# %%
img = cv2.imread(input_img, cv2.IMREAD_GRAYSCALE)
denoised_img = cv2.bilateralFilter(img, 9, 75, 75)
plt.imshow(denoised_img)

# %%
denoised_color_img = cv2.cvtColor(denoised_img, cv2.COLOR_GRAY2BGR)
plt.imshow(denoised_color_img)

# %%
cv2.imwrite(os.path.join(output_dir, 'denoised2.png'), denoised_img)
# Out:
# True
